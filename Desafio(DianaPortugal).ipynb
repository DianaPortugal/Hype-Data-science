# %% [markdown]
# <a href="https://colab.research.google.com/github/DianaPortugal/Hype-Data-science/blob/main/Desafio(DianaPortugal).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Olá! Esse o desafio relativo ao Primeiro Contato com o Google Colab.
#
# Aqui você poderá por em prática os seus conhecimentos recém adquiridos. Use as células abaixo para realizar as tarefas propostas.

# %% [markdown]
# # Tarefa 1
#
# "monte o seu drive"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Tarefa 2
#
# Procure um Dataset que voce tenha interesse no Kaggle. Se tiver dificuldade escolha um dos abaixo:
#
# - https://www.kaggle.com/datasets/alphiree/cardiovascular-diseases-risk-prediction-dataset
# - https://www.kaggle.com/datasets/arnavsmayan/netflix-userbase-dataset
# - https://www.kaggle.com/datasets/nelgiriyewithana/countries-of-the-world-2023

# %% [markdown]
# # Tarefa 3
#
# importe o seu Dataset

# %%
import pandas as pd

# %%
df = pd.read_csv("drive/MyDrive/Netflix Userbase.csv")

# %% [markdown]
# # Tarefa 4
#
# obtenha algumas medidas desse Dataframe

# %%
df.head()
# Out:
#    User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0        1             Basic               10  15-01-22          10-06-23
# 1        2           Premium               15  05-09-21          22-06-23
# 2        3          Standard               12  28-02-23          27-06-23
# 3        4          Standard               12  10-07-22          26-06-23
# 4        5             Basic               10  01-05-23          28-06-23
#
#           Country  Age  Gender      Device Plan Duration
# 0   United States   28    Male  Smartphone       1 Month
# 1          Canada   35  Female      Tablet       1 Month
# 2  United Kingdom   42    Male    Smart TV       1 Month
# 3       Australia   51  Female      Laptop       1 Month
# 4         Germany   33    Male  Smartphone       1 Month

# %%
df.head(10)
# Out:
#    User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0        1             Basic               10  15-01-22          10-06-23
# 1        2           Premium               15  05-09-21          22-06-23
# 2        3          Standard               12  28-02-23          27-06-23
# 3        4          Standard               12  10-07-22          26-06-23
# 4        5             Basic               10  01-05-23          28-06-23
# 5        6           Premium               15  18-03-22          27-06-23
# 6        7          Standard               12  09-12-21          25-06-23
# 7        8             Basic               10  02-04-23          24-06-23
# 8        9          Standard               12  20-10-22          23-06-23
# 9       10           Premium               15  07-01-23          22-06-23
#
#           Country  Age  Gender      Device Plan Duration
# 0   United States   28    Male  Smartphone       1 Month
# ...

# %%
df.tail()
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
#             Country  Age  Gender    Device Plan Duration
# 2495          Spain   28  Female  Smart TV       1 Month
# 2496          Spain   33  Female  Smart TV       1 Month
# 2497  United States   38    Male    Laptop       1 Month
# 2498         Canada   48  Female    Tablet       1 Month
# 2499  United States   35  Female  Smart TV       1 Month

# %%
df.tail(10)
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 2490     2491           Premium               13  18-07-22          11-07-23
# 2491     2492             Basic               14  19-07-22          12-07-23
# 2492     2493          Standard               11  20-07-22          11-07-23
# 2493     2494           Premium               12  21-07-22          15-07-23
# 2494     2495             Basic               15  23-07-22          12-07-23
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
#             Country  Age  Gender      Device Plan Duration
# 2490         France   41  Female  Smartphone       1 Month
# ...

# %%
df.sample(5)
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 1158     1159          Standard               15  25-06-22          01-07-23
# 2004     2005             Basic               10  13-07-22          09-07-23
# 1786     1787             Basic               11  07-07-22          07-07-23
# 385       386             Basic               14  11-07-22          26-06-23
# 1291     1292             Basic               12  30-06-22          04-07-23
#
#             Country  Age  Gender    Device Plan Duration
# 1158          Spain   41    Male    Laptop       1 Month
# 2004  United States   35  Female    Laptop       1 Month
# 1786         Brazil   28    Male    Laptop       1 Month
# 385          France   48    Male    Tablet       1 Month
# 1291         Brazil   30  Female  Smart TV       1 Month

# %%
df.shape
# Out:
# (2500, 10)

# %%
df.describe()
# Out:
#           User ID  Monthly Revenue          Age
# count  2500.00000      2500.000000  2500.000000
# mean   1250.50000        12.508400    38.795600
# std     721.83216         1.686851     7.171778
# min       1.00000        10.000000    26.000000
# 25%     625.75000        11.000000    32.000000
# 50%    1250.50000        12.000000    39.000000
# 75%    1875.25000        14.000000    45.000000
# max    2500.00000        15.000000    51.000000

# %%
df.columns
# Out:
# Index(['User ID', 'Subscription Type', 'Monthly Revenue', 'Join Date',
#        'Last Payment Date', 'Country', 'Age', 'Gender', 'Device',
#        'Plan Duration'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User ID            2500 non-null   int64
#  1   Subscription Type  2500 non-null   object
#  2   Monthly Revenue    2500 non-null   int64
#  3   Join Date          2500 non-null   object
#  4   Last Payment Date  2500 non-null   object
#  5   Country            2500 non-null   object
#  6   Age                2500 non-null   int64
#  7   Gender             2500 non-null   object
#  8   Device             2500 non-null   object
#  9   Plan Duration      2500 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 195.4+ KB

# %% [markdown]
# # Tarefa 5
#
# examine o Dataframe, trate valores nulos e linhas duplicadas.

# %%
df.isnull()
# Out:
#       User ID  Subscription Type  Monthly Revenue  Join Date  \
# 0       False              False            False      False
# 1       False              False            False      False
# 2       False              False            False      False
# 3       False              False            False      False
# 4       False              False            False      False
# ...       ...                ...              ...        ...
# 2495    False              False            False      False
# 2496    False              False            False      False
# 2497    False              False            False      False
# 2498    False              False            False      False
# 2499    False              False            False      False
#
#       Last Payment Date  Country    Age  Gender  Device  Plan Duration
# 0                 False    False  False   False   False          False
# 1                 False    False  False   False   False          False
# ...

# %%
df.isnull().sum()
# Out:
# User ID              0
# Subscription Type    0
# Monthly Revenue      0
# Join Date            0
# Last Payment Date    0
# Country              0
# Age                  0
# Gender               0
# Device               0
# Plan Duration        0
# dtype: int64

# %%
df = df.dropna()
df
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# 1           2           Premium               15  05-09-21          22-06-23
# 2           3          Standard               12  28-02-23          27-06-23
# 3           4          Standard               12  10-07-22          26-06-23
# 4           5             Basic               10  01-05-23          28-06-23
# ...       ...               ...              ...       ...               ...
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2495    False
# 2496    False
# 2497    False
# 2498    False
# 2499    False
# Length: 2500, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df1 = df.drop_duplicates()
df1
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# 1           2           Premium               15  05-09-21          22-06-23
# 2           3          Standard               12  28-02-23          27-06-23
# 3           4          Standard               12  10-07-22          26-06-23
# 4           5             Basic               10  01-05-23          28-06-23
# ...       ...               ...              ...       ...               ...
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
# ...

# %% [markdown]
# # Tarefa 6
#
# Extraia algumas colunas (Series) do Dataframe

# %%
df['Plan Duration']
# Out:
# 0       1 Month
# 1       1 Month
# 2       1 Month
# 3       1 Month
# 4       1 Month
#          ...
# 2495    1 Month
# 2496    1 Month
# 2497    1 Month
# 2498    1 Month
# 2499    1 Month
# Name: Plan Duration, Length: 2500, dtype: object

# %%
df['Subscription Type']
# Out:
# 0          Basic
# 1        Premium
# 2       Standard
# 3       Standard
# 4          Basic
#           ...
# 2495     Premium
# 2496       Basic
# 2497    Standard
# 2498    Standard
# 2499       Basic
# Name: Subscription Type, Length: 2500, dtype: object

# %%
df['Monthly Revenue']
# Out:
# 0       10
# 1       15
# 2       12
# 3       12
# 4       10
#         ..
# 2495    14
# 2496    15
# 2497    12
# 2498    13
# 2499    15
# Name: Monthly Revenue, Length: 2500, dtype: int64

# %% [markdown]
# # Tarefa 7
#
# Obtenha algumas medidas dessas colunas (Series)

# %%
Lista = df['Plan Duration']
Lista
# Out:
# 0       1 Month
# 1       1 Month
# 2       1 Month
# 3       1 Month
# 4       1 Month
#          ...
# 2495    1 Month
# 2496    1 Month
# 2497    1 Month
# 2498    1 Month
# 2499    1 Month
# Name: Plan Duration, Length: 2500, dtype: object

# %%
Lista[520]
# Out:
# '1 Month'

# %%
Lista[30:40]
# Out:
# 30    1 Month
# 31    1 Month
# 32    1 Month
# 33    1 Month
# 34    1 Month
# 35    1 Month
# 36    1 Month
# 37    1 Month
# 38    1 Month
# 39    1 Month
# Name: Plan Duration, dtype: object

# %%
Lista[1000:-1000]
# Out:
# 1000    1 Month
# 1001    1 Month
# 1002    1 Month
# 1003    1 Month
# 1004    1 Month
#          ...
# 1495    1 Month
# 1496    1 Month
# 1497    1 Month
# 1498    1 Month
# 1499    1 Month
# Name: Plan Duration, Length: 500, dtype: object

# %%
Lista2 = df['Subscription Type']
Lista2
# Out:
# 0          Basic
# 1        Premium
# 2       Standard
# 3       Standard
# 4          Basic
#           ...
# 2495     Premium
# 2496       Basic
# 2497    Standard
# 2498    Standard
# 2499       Basic
# Name: Subscription Type, Length: 2500, dtype: object

# %%
Lista2[2495]
# Out:
# 'Premium'

# %%
Lista2[2000:-200]
# Out:
# 2000     Premium
# 2001       Basic
# 2002    Standard
# 2003    Standard
# 2004       Basic
#           ...
# 2295     Premium
# 2296       Basic
# 2297    Standard
# 2298     Premium
# 2299       Basic
# Name: Subscription Type, Length: 300, dtype: object

# %%
Lista3 = df['Monthly Revenue']
Lista3
# Out:
# 0       10
# 1       15
# 2       12
# 3       12
# 4       10
#         ..
# 2495    14
# 2496    15
# 2497    12
# 2498    13
# 2499    15
# Name: Monthly Revenue, Length: 2500, dtype: int64

# %%
Lista3[812]
# Out:
# 10

# %%
Lista3[376:-456]
# Out:
# 376     12
# 377     14
# 378     10
# 379     15
# 380     10
#         ..
# 2039    15
# 2040    10
# 2041    10
# 2042    12
# 2043    12
# Name: Monthly Revenue, Length: 1668, dtype: int64

# %%
Lista3[1200:1218]
# Out:
# 1200    10
# 1201    15
# 1202    12
# 1203    13
# 1204    12
# 1205    13
# 1206    12
# 1207    11
# 1208    11
# 1209    14
# 1210    10
# 1211    13
# 1212    10
# 1213    10
# 1214    13
# 1215    15
# 1216    12
# 1217    13
# Name: Monthly Revenue, dtype: int64

# %% [markdown]
# # Tarefa 8
#
# Extraia linhas de um dataset baseado no valor de uma variável específica

# %%
Lista4 = df[['Plan Duration', 'Subscription Type', 'Monthly Revenue']]
Lista4
# Out:
#      Plan Duration Subscription Type  Monthly Revenue
# 0          1 Month             Basic               10
# 1          1 Month           Premium               15
# 2          1 Month          Standard               12
# 3          1 Month          Standard               12
# 4          1 Month             Basic               10
# ...            ...               ...              ...
# 2495       1 Month           Premium               14
# 2496       1 Month             Basic               15
# 2497       1 Month          Standard               12
# 2498       1 Month          Standard               13
# 2499       1 Month             Basic               15
#
# [2500 rows x 3 columns]

# %%
Lista4.iloc[5]
# Out:
# Plan Duration        1 Month
# Subscription Type    Premium
# Monthly Revenue           15
# Name: 5, dtype: object

# %%
Lista4.iloc[3:18]
# Out:
#    Plan Duration Subscription Type  Monthly Revenue
# 3        1 Month          Standard               12
# 4        1 Month             Basic               10
# 5        1 Month           Premium               15
# 6        1 Month          Standard               12
# 7        1 Month             Basic               10
# 8        1 Month          Standard               12
# 9        1 Month           Premium               15
# 10       1 Month             Basic               10
# 11       1 Month           Premium               15
# 12       1 Month          Standard               12
# 13       1 Month             Basic               10
# 14       1 Month          Standard               12
# 15       1 Month           Premium               15
# 16       1 Month             Basic               10
# 17       1 Month          Standard               12

# %%
Lista5 = df[df['Subscription Type'] == 'Premium']
Lista5.head()
# Out:
#     User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 1         2           Premium               15  05-09-21          22-06-23
# 5         6           Premium               15  18-03-22          27-06-23
# 9        10           Premium               15  07-01-23          22-06-23
# 11       12           Premium               15  23-03-23          28-06-23
# 15       16           Premium               15  07-04-22          27-06-23
#
#    Country  Age  Gender    Device Plan Duration
# 1   Canada   35  Female    Tablet       1 Month
# 5   France   29  Female  Smart TV       1 Month
# 9    Italy   44  Female  Smart TV       1 Month
# 11  Canada   45    Male    Tablet       1 Month
# 15  France   36    Male    Tablet       1 Month

# %%
Lista6 = df[(df['Subscription Type'] == 'Premium') & (df['Country'] == 'Canada')]
Lista6.head()
# Out:
#      User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 1          2           Premium               15  05-09-21          22-06-23
# 11        12           Premium               15  23-03-23          28-06-23
# 151      152           Premium               14  23-11-22          27-06-23
# 161      162           Premium               15  19-04-22          25-06-23
# 301      302           Premium               11  14-09-22          27-06-23
#
#     Country  Age  Gender  Device Plan Duration
# 1    Canada   35  Female  Tablet       1 Month
# 11   Canada   45    Male  Tablet       1 Month
# 151  Canada   33  Female  Tablet       1 Month
# 161  Canada   31    Male  Laptop       1 Month
# 301  Canada   44    Male  Tablet       1 Month

# %% [markdown]
# # Tarefa 8
#
# Realize um agrupamento de uma coluna com a função groupby()

# %%
df.groupby('Subscription Type').mean()
# Out:
# <ipython-input-38-58410d20fb1e>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Subscription Type').mean()
#                        User ID  Monthly Revenue        Age
# Subscription Type
# Basic              1251.711712        12.481481  38.828829
# Premium            1249.165075        12.590723  38.512960
# Standard           1250.197917        12.464844  39.022135
